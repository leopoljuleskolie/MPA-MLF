# %% [markdown]
# <a href="https://colab.research.google.com/github/leopoljuleskolie/MPA-MLF/blob/main/Lab_05_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MPA-MLF, Lab 5 - Feedforward Neural Networks

# %% [markdown]
# These exercises are focused on dealing with neural networks. It is strongly recommended to use google collab for these pc labs. Why? Google collab offers a free GPU capacity to train machine learning models. Training NN on GPU can drastically speed up the training process. You can turn on the GPU accelerator in: Runtime -> Change runtime type -> GPU,

# %% [markdown]
# ## The basic terminology

# %% [markdown]
# ### Neural Networks

# %% [markdown]
# Think of a neural network as a complex web of neurons (or nodes) that are interconnected to process information, similar to how the human brain works. Each neuron in this network can receive inputs, process them, and pass on the output to other neurons. The goal of a neural network is to transform the inputs (e.g., images, texts, numbers) into a desired output (e.g., identifying what's in an image, translating text, etc.).

# %% [markdown]
# ![title](img/network.png)

# %% [markdown]
# ### Layers

# %% [markdown]
# A neural network is made up of layers: the input layer (where the data enters the network), one or more hidden layers (where most of the processing happens), and the output layer (where the final prediction is made). You can think of each layer as a filter that increasingly refines the information as it passes through the network. In our case, we will discuss feedforward, fully-connected neural networks. Fully connected means that every neuron in layer *n* is connected by a weighted connection with all neurons in the layers *n+1*. Feedforward means that data are passed in one direction only, there are no reccurent connections (feedback loops) exist.

# %% [markdown]
# ![title](img/Neural_network.png)

# %% [markdown]
# ### Neuron

# %% [markdown]
# A neuron, or node, is the basic unit of a neural network. It receives input, applies a weight (significance) to that input, adds a bias (a constant value to ensure the neuron activates correctly), and then uses an activation function to determine whether and how strongly to pass its signal to the next layer. Each neuron contributes to the network's ability to make accurate predictions or decisions.|

# %% [markdown]
# ![title](img/neuron.png)

# %% [markdown]
# ### Neuron in the input layer

# %% [markdown]
# In the input layer the input neurons are composed of identity only, that means everying that comes to the input comes directly to the output

# %% [markdown]
# ### Training

# %% [markdown]
# Training a neural network involves feeding it with data for which the correct output is known, allowing the network to adjust its weights and biases to minimize the difference between its predictions and the actual truths. This process is repeated numerous times with many data examples.

# %% [markdown]
# ### Loss Function

# %% [markdown]
# A loss function measures how well the neural network is performing, meaning how close or far its predictions are from the actual values. The goal of training is to minimize this loss, or error, making the network's predictions as accurate as possible.

# %% [markdown]
# ## Exercise 1 - XOR problem

# %% [markdown]
# During the last lecture, we saw that the single perceptron model with a step function could be used only for solving linearly-separable classification problems. Because of that, a single perceptron can not be trained to be able to behave like an XOR gate. To approximate the XOR gate using a neural network, we need to use the following structure:

# %% [markdown]
# ![nn.png](data:image/png;base64,...)

# %% [markdown]
# The above structure contains three layers: two neurons in the input layer (blue), two in the hidden layer and one in the output layer (yellow). The input layer represents the identity functions (the outputs are equal to the inputs)

# %% [markdown]
# We will use *Keras* API to build and train our neural network. Keras is an open-source neural network library written in Python. It is designed to enable fast experimentation with deep neural networks and provides a high-level API for building and training neural networks.

# %% [markdown]
# ### 0. First import libraries

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. prepare data

# %% [markdown]
# In this part, the task would be to prepade our dataset, basically it is the logic table for *XOR* function

# %%
X = [[0, 0], [0, 1], [1, 0], [1, 1]]
y = [0, 1, 1, 0]

# %% [markdown]
# ### 2. Creating the model

# %% [markdown]
# To create a model of NN that is in the picture above, run the following cell

# %%
model = Sequential()
model.add(InputLayer(input_shape=(2)))
model.add(Dense(2, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# **Sequential** is a model type used in Keras for building feedforward neural networks. It is called "sequential" because the layers are stacked sequentially on top of each other, and the output of one layer is passed as input to the next layer.
#
# To create a sequential model, instantiate a Sequential object and then add layers to it using the **add()** method. There are many layers that Keras offers. We will use *Dense layer*
#
# **Dense layer** represents a fully connected layer, which means that every neuron in the layer is connected to every neuron in the previous layer. In each layer, we will specify an activation function and the number of neurons that layer contains. The input layer is not defined as a dense layer, but instead of that, we will specify the *input_dim* parameter in the layer that follows the input layer. *input_dim* parameter specifies the number of neurons in the input layer

# %% [markdown]
# ### 3. Compile the model

# %% [markdown]
# To compile yor model run:

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# **keras.complile()** is used to configure the learning process before training the model.
# We need to specify 3 parameters:
# - *loss*, *optimizer* and *metrics*
#
# - as our loss function (error function/objective function), we will choose *binary_crossentropy* - loss function often used for binary classification
#
# - *optimizer* is optimization algorithm used for optimizing weights in our training process, we will choose *stochastic gradient descent*
#
# - *metrics* is metric user for model evaluation

# %% [markdown]
# ### 4. Model training

# %% [markdown]
# In the lecture, we talked about training the Multi-layer perceptron. The training process consists of the following steps:
#
# 1. Weight initialization
# 2. Forward Propagation
# 3. Compute Loss
# 4. Backpropagation
# 5. Update Weights
# 6. Repeat 2->6 until maximum epochs are reached
#
# When training a machine learning model, the training data is usually divided into batches (parts), and the model updates its weights after processing each batch. The batch size determines how many training examples are included in each batch.
#
# For example, we have 10,000 training examples and a batch size of 100. In this case, the training data would be divided into 100 batches of 100 examples each. During training, the model would process each batch, calculate the loss or error, and update its weights based on the average of the errors in that batch. In other words, if we batch equal to 1. we will update the weights 10 000 times. If we have batch size == 100, we will update the weights only 100 times

# %% [markdown]
# To train your model, run the following line of the code:

# %%
history = model.fit(X, y, epochs=2000, batch_size=1, verbose=1)
# Out:
# Epoch 1/2000
# 4/4 [==============================] - 2s 9ms/step - loss: 0.7208 - accuracy: 0.5000
# Epoch 2/2000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7205 - accuracy: 0.2500
# Epoch 3/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7204 - accuracy: 0.5000
# Epoch 4/2000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7200 - accuracy: 0.2500
# Epoch 5/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7198 - accuracy: 0.5000
# Epoch 6/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7185 - accuracy: 0.5000
# Epoch 7/2000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7195 - accuracy: 0.2500
# Epoch 8/2000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7194 - accuracy: 0.2500
# Epoch 9/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7179 - accuracy: 0.2500
# Epoch 10/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7193 - accuracy: 0.2500
# Epoch 11/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7179 - accuracy: 0.2500
# Epoch 12/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7190 - accuracy: 0.2500
# Epoch 13/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7189 - accuracy: 0.0000e+00
# Epoch 14/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7190 - accuracy: 0.0000e+00
# Epoch 15/2000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7187 - accuracy: 0.5000
# Epoch 16/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7187 - accuracy: 0.0000e+00
# Epoch 17/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7187 - accuracy: 0.2500
# Epoch 18/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7184 - accuracy: 0.2500
# Epoch 19/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7183 - accuracy: 0.2500
# Epoch 20/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7168 - accuracy: 0.2500
# Epoch 21/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7168 - accuracy: 0.2500
# Epoch 22/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7180 - accuracy: 0.5000
# Epoch 23/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7167 - accuracy: 0.5000
# Epoch 24/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7179 - accuracy: 0.5000
# Epoch 25/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7165 - accuracy: 0.2500
# Epoch 26/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7177 - accuracy: 0.0000e+00
# Epoch 27/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7176 - accuracy: 0.2500
# Epoch 28/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7176 - accuracy: 0.2500
# Epoch 29/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7175 - accuracy: 0.2500
# Epoch 30/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7158 - accuracy: 0.5000
# Epoch 31/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7171 - accuracy: 0.0000e+00
# Epoch 32/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7157 - accuracy: 0.2500
# Epoch 33/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7155 - accuracy: 0.5000
# Epoch 34/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7170 - accuracy: 0.2500
# Epoch 35/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7169 - accuracy: 0.5000
# Epoch 36/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7168 - accuracy: 0.2500
# Epoch 37/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7166 - accuracy: 0.0000e+00
# Epoch 38/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7166 - accuracy: 0.2500
# Epoch 39/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7163 - accuracy: 0.2500
# Epoch 40/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7164 - accuracy: 0.5000
# Epoch 41/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7149 - accuracy: 0.2500
# Epoch 42/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7147 - accuracy: 0.5000
# Epoch 43/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7160 - accuracy: 0.2500
# Epoch 44/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7146 - accuracy: 0.2500
# Epoch 45/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7146 - accuracy: 0.5000
# Epoch 46/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7159 - accuracy: 0.0000e+00
# Epoch 47/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7159 - accuracy: 0.2500
# Epoch 48/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7159 - accuracy: 0.5000
# Epoch 49/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7156 - accuracy: 0.0000e+00
# Epoch 50/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7142 - accuracy: 0.5000
# Epoch 51/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7152 - accuracy: 0.5000
# Epoch 52/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7139 - accuracy: 0.2500
# Epoch 53/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7139 - accuracy: 0.2500
# Epoch 54/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7137 - accuracy: 0.2500
# Epoch 55/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7151 - accuracy: 0.2500
# Epoch 56/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7137 - accuracy: 0.2500
# Epoch 57/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7134 - accuracy: 0.2500
# Epoch 58/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7146 - accuracy: 0.0000e+00
# Epoch 59/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7147 - accuracy: 0.5000
# Epoch 60/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7144 - accuracy: 0.2500
# Epoch 61/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7145 - accuracy: 0.2500
# Epoch 62/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7144 - accuracy: 0.2500
# Epoch 63/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7141 - accuracy: 0.2500
# Epoch 64/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7141 - accuracy: 0.5000
# Epoch 65/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7139 - accuracy: 0.2500
# Epoch 66/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7128 - accuracy: 0.2500
# Epoch 67/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7138 - accuracy: 0.2500
# Epoch 68/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7139 - accuracy: 0.5000
# Epoch 69/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7137 - accuracy: 0.5000
# Epoch 70/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7136 - accuracy: 0.5000
# Epoch 71/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7134 - accuracy: 0.2500
# Epoch 72/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7123 - accuracy: 0.2500
# Epoch 73/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7133 - accuracy: 0.2500
# Epoch 74/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7133 - accuracy: 0.5000
# Epoch 75/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7131 - accuracy: 0.5000
# Epoch 76/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7130 - accuracy: 0.5000
# Epoch 77/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7130 - accuracy: 0.2500
# Epoch 78/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7114 - accuracy: 0.5000
# Epoch 79/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7128 - accuracy: 0.7500
# Epoch 80/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7125 - accuracy: 0.5000
# Epoch 81/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7124 - accuracy: 0.2500
# Epoch 82/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7112 - accuracy: 0.2500
# Epoch 83/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7122 - accuracy: 0.2500
# Epoch 84/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7121 - accuracy: 0.5000
# Epoch 85/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7120 - accuracy: 0.2500
# Epoch 86/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7108 - accuracy: 0.2500
# Epoch 87/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7118 - accuracy: 0.2500
# Epoch 88/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7117 - accuracy: 0.5000
# Epoch 89/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7103 - accuracy: 0.5000
# Epoch 90/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7117 - accuracy: 0.5000
# Epoch 91/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7113 - accuracy: 0.5000
# Epoch 92/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7101 - accuracy: 0.2500
# Epoch 93/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7113 - accuracy: 0.2500
# Epoch 94/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7100 - accuracy: 0.2500
# Epoch 95/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7110 - accuracy: 0.2500
# Epoch 96/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7111 - accuracy: 0.5000
# Epoch 97/2000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7095 - accuracy: 0.5000
# Epoch 98/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7105 - accuracy: 0.5000
# Epoch 99/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7091 - accuracy: 0.5000
# Epoch 100/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7093 - accuracy: 0.5000
# Epoch 101/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7103 - accuracy: 0.5000
# Epoch 102/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7102 - accuracy: 0.5000
# Epoch 103/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7088 - accuracy: 0.5000
# Epoch 104/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7103 - accuracy: 0.5000
# Epoch 105/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7101 - accuracy: 0.5000
# Epoch 106/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7099 - accuracy: 0.5000
# Epoch 107/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7096 - accuracy: 0.2500
# Epoch 108/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7094 - accuracy: 0.5000
# Epoch 109/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7080 - accuracy: 0.5000
# Epoch 110/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7091 - accuracy: 0.2500
# Epoch 111/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7077 - accuracy: 0.5000
# Epoch 112/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7079 - accuracy: 0.5000
# Epoch 113/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7088 - accuracy: 0.5000
# Epoch 114/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7087 - accuracy: 0.2500
# Epoch 115/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7073 - accuracy: 0.5000
# Epoch 116/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7086 - accuracy: 0.5000
# Epoch 117/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7082 - accuracy: 0.2500
# Epoch 118/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7081 - accuracy: 0.2500
# Epoch 119/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7080 - accuracy: 0.2500
# Epoch 120/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7080 - accuracy: 0.7500
# Epoch 121/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7079 - accuracy: 0.5000
# Epoch 122/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7076 - accuracy: 0.2500
# Epoch 123/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7077 - accuracy: 0.5000
# Epoch 124/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7062 - accuracy: 0.7500
# Epoch 125/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7072 - accuracy: 0.7500
# Epoch 126/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7073 - accuracy: 0.2500
# Epoch 127/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7069 - accuracy: 0.2500
# Epoch 128/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7056 - accuracy: 0.5000
# Epoch 129/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7067 - accuracy: 0.5000
# Epoch 130/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7067 - accuracy: 0.5000
# Epoch 131/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7052 - accuracy: 0.5000
# Epoch 132/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7065 - accuracy: 0.2500
# Epoch 133/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7049 - accuracy: 0.5000
# Epoch 134/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7049 - accuracy: 0.2500
# Epoch 135/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7060 - accuracy: 0.7500
# Epoch 136/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7045 - accuracy: 0.7500
# Epoch 137/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7045 - accuracy: 0.2500
# Epoch 138/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7043 - accuracy: 0.2500
# Epoch 139/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7040 - accuracy: 0.5000
# Epoch 140/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7053 - accuracy: 0.2500
# Epoch 141/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7051 - accuracy: 0.5000
# Epoch 142/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7047 - accuracy: 0.7500
# Epoch 143/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7048 - accuracy: 0.2500
# Epoch 144/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7032 - accuracy: 0.5000
# Epoch 145/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7045 - accuracy: 0.5000
# Epoch 146/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7042 - accuracy: 0.5000
# Epoch 147/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7027 - accuracy: 0.5000
# Epoch 148/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7038 - accuracy: 0.5000
# Epoch 149/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7038 - accuracy: 0.5000
# Epoch 150/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7023 - accuracy: 0.5000
# Epoch 151/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7036 - accuracy: 0.5000
# Epoch 152/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7033 - accuracy: 0.7500
# Epoch 153/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7031 - accuracy: 0.7500
# Epoch 154/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7016 - accuracy: 0.7500
# Epoch 155/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7014 - accuracy: 0.5000
# Epoch 156/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7024 - accuracy: 0.2500
# Epoch 157/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7023 - accuracy: 0.5000
# Epoch 158/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7020 - accuracy: 0.7500
# Epoch 159/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7021 - accuracy: 0.2500
# Epoch 160/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7019 - accuracy: 0.7500
# Epoch 161/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7015 - accuracy: 0.2500
# Epoch 162/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7015 - accuracy: 0.5000
# Epoch 163/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7014 - accuracy: 0.5000
# Epoch 164/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6998 - accuracy: 0.5000
# Epoch 165/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7008 - accuracy: 0.7500
# Epoch 166/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6994 - accuracy: 0.5000
# Epoch 167/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7004 - accuracy: 0.5000
# Epoch 168/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7004 - accuracy: 0.7500
# Epoch 169/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7001 - accuracy: 0.5000
# Epoch 170/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6988 - accuracy: 0.5000
# Epoch 171/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6985 - accuracy: 0.5000
# Epoch 172/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6996 - accuracy: 0.5000
# Epoch 173/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6995 - accuracy: 0.7500
# Epoch 174/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6993 - accuracy: 0.5000
# Epoch 175/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6979 - accuracy: 0.2500
# Epoch 176/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6978 - accuracy: 0.5000
# Epoch 177/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6976 - accuracy: 0.5000
# Epoch 178/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6975 - accuracy: 0.5000
# Epoch 179/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6974 - accuracy: 0.5000
# Epoch 180/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6973 - accuracy: 0.5000
# Epoch 181/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6972 - accuracy: 0.5000
# Epoch 182/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6972 - accuracy: 0.5000
# Epoch 183/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6966 - accuracy: 0.7500
# Epoch 184/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6971 - accuracy: 0.7500
# Epoch 185/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6955 - accuracy: 0.5000
# Epoch 186/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6966 - accuracy: 0.5000
# Epoch 187/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6963 - accuracy: 0.5000
# Epoch 188/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6962 - accuracy: 0.7500
# Epoch 189/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6959 - accuracy: 0.5000
# Epoch 190/2000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6956 - accuracy: 0.5000
# Epoch 191/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6957 - accuracy: 0.5000
# Epoch 192/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6953 - accuracy: 0.5000
# Epoch 193/2000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6952 - accuracy: 0.5000
# Epoch 194/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6950 - accuracy: 0.5000
# Epoch 195/2000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6945 - accuracy: 0.7500
# Epoch 196/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6930 - accuracy: 0.5000
# Epoch 197/2000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6941 - accuracy: 0.7500
# Epoch 198/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6925 - accuracy: 0.7500
# Epoch 199/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6938 - accuracy: 0.2500
# Epoch 200/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6935 - accuracy: 0.5000
# Epoch 201/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6930 - accuracy: 0.5000
# Epoch 202/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6929 - accuracy: 0.5000
# Epoch 203/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6926 - accuracy: 0.5000
# Epoch 204/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6922 - accuracy: 0.7500
# Epoch 205/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6908 - accuracy: 0.7500
# Epoch 206/2000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6920 - accuracy: 0.7500
# Epoch 207/2000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6918 - accuracy: 0.5000
# Epoch 208/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6914 - accuracy: 0.5000
# Epoch 209/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6897 - accuracy: 0.2500
# Epoch 210/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6896 - accuracy: 0.5000
# Epoch 211/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6907 - accuracy: 0.5000
# Epoch 212/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6892 - accuracy: 0.2500
# Epoch 213/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6899 - accuracy: 0.7500
# Epoch 214/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6897 - accuracy: 0.5000
# Epoch 215/2000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6882 - accuracy: 0.2500
# Epoch 216/2000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6879 - accuracy: 0.7500
# Epoch 217/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6891 - accuracy: 0.7500
# Epoch 218/2000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6886 - accuracy: 0.7500
# Epoch 219/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6883 - accuracy: 0.7500
# Epoch 220/2000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6880 - accuracy: 0.7500
# Epoch 221/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6879 - accuracy: 0.7500
# Epoch 222/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6862 - accuracy: 0.5000
# Epoch 223/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6861 - accuracy: 0.5000
# Epoch 224/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6870 - accuracy: 0.5000
# Epoch 225/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6870 - accuracy: 0.7500
# Epoch 226/2000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6865 - accuracy: 0.7500
# Epoch 227/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6861 - accuracy: 0.5000
# Epoch 228/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6845 - accuracy: 0.7500
# Epoch 229/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6855 - accuracy: 0.7500
# Epoch 230/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6850 - accuracy: 0.7500
# Epoch 231/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6849 - accuracy: 0.7500
# Epoch 232/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6843 - accuracy: 0.7500
# Epoch 233/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6830 - accuracy: 0.2500
# Epoch 234/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6826 - accuracy: 0.7500
# Epoch 235/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6824 - accuracy: 0.5000
# Epoch 236/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6833 - accuracy: 0.5000
# Epoch 237/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6815 - accuracy: 0.7500
# Epoch 238/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6812 - accuracy: 0.7500
# Epoch 239/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6810 - accuracy: 0.7500
# Epoch 240/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6807 - accuracy: 0.2500
# Epoch 241/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6815 - accuracy: 0.7500
# Epoch 242/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6799 - accuracy: 0.2500
# Epoch 243/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6810 - accuracy: 0.7500
# Epoch 244/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6791 - accuracy: 0.7500
# Epoch 245/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6788 - accuracy: 0.7500
# Epoch 246/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6799 - accuracy: 0.5000
# Epoch 247/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6783 - accuracy: 0.7500
# Epoch 248/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6791 - accuracy: 0.7500
# Epoch 249/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6789 - accuracy: 0.7500
# Epoch 250/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6773 - accuracy: 0.7500
# Epoch 251/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.
2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 1968/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 1969/2000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 1970/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 1971/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 1972/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 1973/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 1974/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 1975/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 1976/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 1977/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 1978/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 1979/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 1980/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 1981/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 1982/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 1983/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 1984/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 1985/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 1986/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 1987/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 1988/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 1989/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 1990/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 1991/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 1992/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 1993/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 1994/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 1995/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 1996/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 1997/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 1998/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 1999/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 2000/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 1.0000

# %% [markdown]
# the method **.fit()**, is used to train the model. We can see that it takes several input parameters:
#  - *X* - input data
#  - *y* - label for the input data
#  - *epochs* number of training epochs (iterations)
#  - *batch_size* - number of samples in each batch
#  - *verbose* - set verbose parameter to see the progress of loss and metrics during the training epochs
#
# These are not the only parameters the .fit() method can take. Check official documentation: https://keras.io/api/models/model_training_apis/
#
# We will set the output of our .fit() function to variable *history*, where the loss and other metrics defined above in the .compile() function during the training are saved.

# %% [markdown]
# ### 5. Model evaluation

# %% [markdown]
# Out training process is finished. To evaluate the performance of our model on test data, tun the following cell of the code:

# %%
loss, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: {:.2f}'.format(accuracy*100))
# Out:
# Accuracy: 100.00

# %% [markdown]
# ### 6. Model predictions

# %%
for id_x, data_sample in enumerate(X):
  prediction = model.predict([data_sample])
  print(f"Data sample is {data_sample}, prediction from model {prediction}, ground_truth {y[id_x]}")
# Out:
# 1/1 [==============================] - 0s 79ms/step
# Data sample is [0, 0], prediction from model [[0.02299569]], ground_truth 0
# 1/1 [==============================] - 0s 29ms/step
# Data sample is [0, 1], prediction from model [[0.98200166]], ground_truth 1
# 1/1 [==============================] - 0s 31ms/step
# Data sample is [1, 0], prediction from model [[0.98200125]], ground_truth 1
# 1/1 [==============================] - 0s 30ms/step
# Data sample is [1, 1], prediction from model [[0.01977743]], ground_truth 0

# %% [markdown]
# ### 7. Display loss function during the training process and acuracy

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.xlabel('n epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ### TASK:
#
# In this part of the exercise, the task would be to play around with the code above to see the influence of hyperparameters.
#
# As we know from the lecture, neural networks contain two types of parameters:
#   1. **Learnable parameters** - *weights* and *biases*. these parameters are adjusted in the training process.
#   2. **Non-learnable parameters (hyperparameters)** - learning_rate, number_of_neurons, number_of_layers, number_of_epochs, type of activation functions in the neurons.., basically any user-defined setting is considered to be hyperparameter
#
#
# Change the following parameters:
# - number of epochs
# - learning_rate
# - activation functions in layers,
# - batch_size,
# - verbose,
# - number of neurons in the hidden layer
#
# Moreover, see the influence on the training process and results.
#
# **Note: Every time we change some hyper-parameters, do not forget to compile the model, to initialize the learnable parameters again**

# %% [markdown]
# ## Exercise 2 - Congressional Voting Data
#
# In the attached dataset, results from congressional voting can be found. Your task is to train a model that can recognize that the politician is *republican* or *democrat* based on voting results. We would follow the general machine learning steps that were described in the lecture.

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Loading dataset

# %% [markdown]
# **First mount your google drive to google colab file.**

# %%
path_to_dataset = '/voting_complete.csv' # change the PATH
pd_dataset = pd.read_csv(path_to_dataset)

# %%
pd_dataset
# Out:
#      Unnamed: 0  Class Name handicapped-infants water-project-cost-sharing  \
# 0             0  republican                   n                          y
# 1             1  republican                   n                          y
# 2             2    democrat                   ?                          y
# 3             3    democrat                   n                          y
# 4             4    democrat                   y                          y
# ..          ...         ...                 ...                        ...
# 430         430  republican                   n                          n
# 431         431    democrat                   n                          n
# 432         432  republican                   n                          ?
# 433         433  republican                   n                          n
# 434         434  republican                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                    ?               y
# 3                                   y                    n               ?
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 430                                 y                    y               y
# 431                                 y                    n               n
# 432                                 n                    y               y
# 433                                 n                    y               y
# 434                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 430                           y                       n
# 431                           n                       y
# 432                           y                       n
# 433                           y                       ?
# 434                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 430                         n          y           y
# 431                         y          y           y
# 432                         n          n           n
# 433                         ?          ?           ?
# 434                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  n                      y
# 4                              y                  ?                      y
# ..                           ...                ...                    ...
# 430                            n                  y                      y
# 431                            n                  n                      n
# 432                            y                  y                      y
# 433                            n                  y                      y
# 434                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       y                 n                                      ?
# 2       y                 n                                      n
# 3       n                 n                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 430     y                 n                                      y
# 431     n                 n                                      y
# 432     y                 n                                      y
# 433     y                 n                                      y
# 434     y                 ?                                      n
#
# [435 rows x 18 columns]

# %% [markdown]
# ### 2. Train/Test Split

# %% [markdown]
# Fistlty we need to split our dataset into train and test. We will use 80% of dataset as our trainset and 20% od dataset as our testset. You can use functions included in *keras*, *scikit-learn*, or you can write your own:

# %%
# define a function for train and test split

def train_test_split(pd_data: pd.DataFrame, test_ratio: float = 0.2) -> tuple:
    pd_dataset = pd_data.copy()
    pd_dataset = pd_dataset[pd_dataset.columns[1:]]
    index = np.arange(len(pd_dataset))
    index = np.random.permutation(index)
    train_ammount = int(len(index)*test_ratio)
    train_ids = index[train_ammount:]
    test_ids = index[:train_ammount]

    train_dataset = pd_dataset[pd_dataset.index.isin(train_ids)].reset_index()
    test_dataset = pd_dataset[pd_dataset.index.isin(test_ids)].reset_index()

    train_dataset = train_dataset[train_dataset.columns[1:]]
    test_dataset = test_dataset[test_dataset.columns[1:]]

    return train_dataset[train_dataset.columns[1:]], train_dataset[train_dataset.columns[0]], test_dataset[test_dataset.columns[1:]], test_dataset[test_dataset.columns[0]]

# %%
x_train, y_train, x_test, y_test = train_test_split(pd_dataset)

# %% [markdown]
# ### 3. Data examination

# %% [markdown]
# The task would be to examine the dataset. Check:
#
# 1. Is it a classification of regression task?
# 2. How many data samples do we have?
# 3. How many features do we have?
# 4. What data types do we have in our dataset?
# 5. Are there any missing values?
# 6. How many labels do we have?

# %%
x_train
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                     n                          y
# 1                     n                          y
# 2                     ?                          y
# 3                     y                          y
# 4                     n                          y
# ..                  ...                        ...
# 343                   y                          n
# 344                   n                          n
# 345                   n                          n
# 346                   n                          ?
# 347                   n                          n
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                    ?               y
# 3                                   y                    n               y
# 4                                   n                    y               y
# ..                                ...                  ...             ...
# 343                                 y                    n               ?
# 344                                 y                    y               y
# 345                                 y                    n               n
# 346                                 n                    y               y
# 347                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 343                           n                       y
# 344                           y                       n
# 345                           n                       y
# 346                           y                       n
# 347                           y                       ?
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 343                         y          y           y
# 344                         n          y           y
# 345                         y          y           y
# 346                         n          n           n
# 347                         ?          ?           ?
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  ?                      y
# 4                              n                  n                      ?
# ..                           ...                ...                    ...
# 343                            n                  y                      n
# 344                            n                  y                      y
# 345                            n                  n                      n
# 346                            y                  y                      y
# 347                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       y                 n                                      ?
# 2       y                 n                                      n
# 3       y                 y                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 343     ?                 y                                      y
# 344     y                 n                                      y
# 345     n                 n                                      y
# 346     y                 n                                      y
# 347     y                 n                                      y
#
# [348 rows x 16 columns]

# %% [markdown]
# ### 4. Data preprocessing

# %% [markdown]
# When you preprocess your traing data, do not forget that you need to apply the same preprocessing also for your test set. For example: If you decide to delete some columns in your train set, you have to delete the same columns in your test set.

# %% [markdown]
# Possible preprocessing steps (try several and see the influence of your preprocessing on your results)
#  - Replace missing values with any data imputation technique ( for example, the most occurring value in the column), then perform one-hot encoding or label encoding of your data
#  - Consider the missing value to be the third category 'unknown' and then perform one-hot encoding or label encoding
#
# The target value also has to be encoded. This can be done by one-hot encoding or label encoding.

# %%
#WRITE YOUR CODE HERE

# %%
#WRITE YOUR CODE HERE

# %% [markdown]
# ### 5. Creating the model

# %% [markdown]
# 1. Create your model using alteast one hidden layer.
#
# *hint: do not create too complex models, this is a very simple task, so it would be enought to use just few neurons in the hidden layers*

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Assume train_data contains your preprocessed training data
# Splitting the data into features (X) and target (y)
X_train = train_data.drop(columns=['target'])  # Features
y_train = train_data['target']  # Target

# Splitting the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Define the model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),  # Hidden layer with 64 neurons and ReLU activation function
    Dense(1, activation='sigmoid')  # Output layer with 1 neuron and sigmoid activation function for binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 64)                192
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 257 (1.00 KB)
# Trainable params: 257 (1.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# 2. Check what *model.summary()* does

# %%
# WRITE YOU CODE HERE
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 64)                192
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 257 (1.00 KB)
# Trainable params: 257 (1.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# 3. Compile the model, choose a suitable loss function, choose gradient to descend optimizer and specify the learning rate, and choose accuracy as our metric

# %%
# WRITE YOUR CODE HERE
from tensorflow.keras.optimizers import Adam

# Compile the model
optimizer = Adam(learning_rate=0.001)  # Specify the learning rate
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# 4. Train the model. Specify the number of epochs and batch size. Now is the time to create a validation dataset. Set 20% of dataset to be a validation dataset

# %%
# WRITE YOUR CODE HERE

# %% [markdown]
# ### 7. Model Evaluation

# %% [markdown]
# 1. First, apply the same preprocessing you did to train set to test set also

# %%
# WRITE YOUR CODE HERE

# %% [markdown]
# 2. Evaluate the model, print final accuracy and loss

# %%
# WRITE YOUR CODE HERE

# %% [markdown]
# 3. Plot loss and validation loss depending on the training epochs into one graph. In another graph, plot accuracy and validation accuracy

# %%
# WRITE YOUR CODE HERE
